# %%
import os
import re
import shutil
import subprocess
from pathlib import Path

# %%
# --- Configuration ---
# Prefix with \\?\ to handle long Windows paths
base_src = r"\\?\C:\Users\holmes\OneDrive - Roskilde Universitet\Isabella Bugge Nielsen's files - Lydfiler"
base_dst = r"D:\legendary_interview"

# Regex to find " - nr XXX" in the folder name
nr_pattern = re.compile(r"-\s*nr\s*(\d+)")

# Regex to find your specific TrLR file (e.g., 251126_130037_TrLR.wav)
file_pattern = re.compile(r".*_\d+_TrLR\.wav", re.IGNORECASE)

def convert_to_flac(src_path, dst_path):
    """Converts WAV to FLAC using FFmpeg"""
    try:
        # -y overwrites existing files; -hide_banner reduces logs
        subprocess.run(['ffmpeg', '-i', src_path, '-y', '-hide_banner', '-loglevel', 'error', dst_path], check=True)
        return True
    except subprocess.CalledProcessError as e:
        print(f"Error converting {src_path}: {e}")
        return False

# --- Main Logic ---
if not os.path.exists(base_dst):
    os.makedirs(base_dst)

# Recursively walk through the OneDrive folder
for root, dirs, files in os.walk(base_src):
    # Search for the "nr" number in the current folder name
    folder_name = os.path.basename(root)
    match = nr_pattern.search(folder_name)
    
    if match:
        nr_id = match.group(1)
        target_folder = os.path.join(base_dst, f"nr {nr_id}")
        
        # Create destination folder if it doesn't exist
        if not os.path.exists(target_folder):
            os.makedirs(target_folder)
            print(f"Created: {target_folder}")

        # Look for the TrLR wav file in this directory or subdirectories
        for file in files:
            if file_pattern.match(file):
                src_file_path = os.path.join(root, file)
                # Change extension for the destination
                flac_filename = file.rsplit('.', 1)[0] + ".flac"
                dst_file_path = os.path.join(target_folder, flac_filename)

                if not os.path.exists(dst_file_path):
                    print(f"Converting: {file} -> nr {nr_id}")
                    convert_to_flac(src_file_path, dst_file_path)
# Out:
# Created: D:\legendary_interview\nr 195
# Converting: 251113_131448_TrLR.WAV -> nr 195
# Created: D:\legendary_interview\nr 194
# Converting: 251124_162941_TrLR.WAV -> nr 194
# Converting: 251124_180254_TrLR.WAV -> nr 194
# Created: D:\legendary_interview\nr 187
# Converting: 251126_101206_TrLR.WAV -> nr 187
# Created: D:\legendary_interview\nr 184
# Created: D:\legendary_interview\nr 183
# Converting: 251124_121129_TrLR.WAV -> nr 183
# Created: D:\legendary_interview\nr 182
# Converting: 111125_082922_TrLR.WAV -> nr 182
# Created: D:\legendary_interview\nr 181
# Converting: 251127_123439_TrLR.WAV -> nr 181
# Converting: 251127_133406_TrLR.WAV -> nr 181
# Created: D:\legendary_interview\nr 180
# Converting: 251127_130936_TrLR.WAV -> nr 180
# Created: D:\legendary_interview\nr 179
# Created: D:\legendary_interview\nr 178
# Converting: 251111_080456_TrLR.WAV -> nr 178
# Created: D:\legendary_interview\nr 177
# Converting: 251202_101654_TrLR.WAV -> nr 177
# Converting: 251202_115007_TrLR.WAV -> nr 177
# Created: D:\legendary_interview\nr 175
# Converting: 251111_075931_TrLR.WAV -> nr 175
# Created: D:\legendary_interview\nr 166
# Converting: 251113_091725_TrLR.WAV -> nr 166
# Created: D:\legendary_interview\nr 160
# Converting: 251112_090747_TrLR.WAV -> nr 160
# Created: D:\legendary_interview\nr 158
# Converting: 251126_163111_TrLR.WAV -> nr 158
# Created: D:\legendary_interview\nr 156
# Converting: 251127_124131_TrLR.WAV -> nr 156
# Created: D:\legendary_interview\nr 154
# Created: D:\legendary_interview\nr 152
# Created: D:\legendary_interview\nr 151
# Converting: 251111_170303_TrLR.WAV -> nr 151
# Created: D:\legendary_interview\nr 150
# Converting: 251126_082058_TrLR.WAV -> nr 150
# Created: D:\legendary_interview\nr 145
# Converting: 251111_160347_TrLR.WAV -> nr 145
# Created: D:\legendary_interview\nr 140
# Converting: 251110_172327_TrLR.WAV -> nr 140
# Created: D:\legendary_interview\nr 139
# Created: D:\legendary_interview\nr 138
# Converting: 251114_125532_TrLR.WAV -> nr 138
# Created: D:\legendary_interview\nr 137
# Converting: 251127_100835_TrLR.WAV -> nr 137
# Created: D:\legendary_interview\nr 136
# Created: D:\legendary_interview\nr 135
# Created: D:\legendary_interview\nr 132
# Converting: 251112_132843_TrLR.WAV -> nr 132
# Created: D:\legendary_interview\nr 128
# Created: D:\legendary_interview\nr 126
# Converting: 251124_083242_TrLR.WAV -> nr 126
# Created: D:\legendary_interview\nr 122
# Converting: 251203_150222_TrLR.WAV -> nr 122
# Created: D:\legendary_interview\nr 121
# Converting: 251112_145100_TrLR.WAV -> nr 121
# Created: D:\legendary_interview\nr 120
# Converting: 251211_100037_TrLR.WAV -> nr 120
# Created: D:\legendary_interview\nr 114
# Converting: 251111_100238_TrLR.WAV -> nr 114
# Created: D:\legendary_interview\nr 112
# Created: D:\legendary_interview\nr 111
# Converting: 251127_150736_TrLR.WAV -> nr 111
# Created: D:\legendary_interview\nr 110
# Converting: 241125_093936_TrLR.WAV -> nr 110
# Converting: 241125_111249_TrLR.WAV -> nr 110
# Created: D:\legendary_interview\nr 108
# Converting: 251114_150824_TrLR.WAV -> nr 108
# Created: D:\legendary_interview\nr 104
# Converting: 251203_170917_TrLR.WAV -> nr 104
# Created: D:\legendary_interview\nr 102
# Converting: 251113_120817_TrLR.WAV -> nr 102
# Created: D:\legendary_interview\nr 99
# Converting: 111125_153019_TrLR.WAV -> nr 99
# Created: D:\legendary_interview\nr 97
# Converting: 251126_140617_TrLR.WAV -> nr 97
# Created: D:\legendary_interview\nr 94
# Converting: 251112_171231_TrLR.WAV -> nr 94
# Created: D:\legendary_interview\nr 92
# Created: D:\legendary_interview\nr 91
# Created: D:\legendary_interview\nr 86
# Converting: 251113_152629_TrLR.WAV -> nr 86
# Created: D:\legendary_interview\nr 83
# Converting: 251124_140725_TrLR.WAV -> nr 83
# Created: D:\legendary_interview\nr 82
# Converting: 251111_120752_TrLR.WAV -> nr 82
# Converting: 251111_122423_TrLR.WAV -> nr 82
# Created: D:\legendary_interview\nr 78
# Converting: 251124_165938_TrLR.WAV -> nr 78
# Created: D:\legendary_interview\nr 77
# Converting: 251113_083647_TrLR.WAV -> nr 77
# Created: D:\legendary_interview\nr 74
# Converting: 251112_093133_TrLR.WAV -> nr 74
# Created: D:\legendary_interview\nr 72
# Converting: 251111_100407_TrLR.WAV -> nr 72
# Created: D:\legendary_interview\nr 71
# Converting: 251125_090601_TrLR.WAV -> nr 71
# Created: D:\legendary_interview\nr 68
# Converting: 251111_175252_TrLR.WAV -> nr 68
# Created: D:\legendary_interview\nr 67
# Created: D:\legendary_interview\nr 66
# Converting: 251114_085857_TrLR.WAV -> nr 66
# Created: D:\legendary_interview\nr 65
# Converting: 251124_151226_TrLR.WAV -> nr 65
# Created: D:\legendary_interview\nr 64
# Converting: 111125_184310_TrLR.WAV -> nr 64
# Created: D:\legendary_interview\nr 62
# Converting: 251127_101630_TrLR.WAV -> nr 62
# Created: D:\legendary_interview\nr 61
# Converting: 251113_163037_TrLR.WAV -> nr 61
# Created: D:\legendary_interview\nr 55
# Converting: 241125_123650_TrLR.WAV -> nr 55
# Created: D:\legendary_interview\nr 52
# Converting: 251113_120952_TrLR.WAV -> nr 52
# Created: D:\legendary_interview\nr 51
# Converting: 251111_145847_TrLR.WAV -> nr 51
# Created: D:\legendary_interview\nr 50
# Converting: 111125_103859_TrLR.WAV -> nr 50
# Created: D:\legendary_interview\nr 48
# Converting: 251112_110336_TrLR.WAV -> nr 48
# Created: D:\legendary_interview\nr 44
# Converting: 251126_080245_TrLR.WAV -> nr 44
# Created: D:\legendary_interview\nr 43
# Converting: 251113_143113_TrLR.WAV -> nr 43
# Created: D:\legendary_interview\nr 37
# Converting: 251111_133512_TrLR.WAV -> nr 37
# Created: D:\legendary_interview\nr 36
# Converting: 251111_172203_TrLR.WAV -> nr 36
# Created: D:\legendary_interview\nr 35
# Converting: 251125_082317_TrLR.WAV -> nr 35
# Created: D:\legendary_interview\nr 34
# Created: D:\legendary_interview\nr 33
# Created: D:\legendary_interview\nr 31
# Converting: 251113_090850_TrLR.WAV -> nr 31
# Created: D:\legendary_interview\nr 23
# Converting: 251114_111427_TrLR.WAV -> nr 23
# Converting: 251114_113244_TrLR.WAV -> nr 23
# Created: D:\legendary_interview\nr 21
# Converting: 251112_093232_TrLR.WAV -> nr 21
# Created: D:\legendary_interview\nr 20
# Converting: 251112_120108_TrLR.WAV -> nr 20
# Created: D:\legendary_interview\nr 16
# Converting: 251125_083416_TrLR.WAV -> nr 16
# Created: D:\legendary_interview\nr 14
# Converting: 251111_154719_TrLR.WAV -> nr 14
# Created: D:\legendary_interview\nr 12
# Created: D:\legendary_interview\nr 10
# Converting: 251124_100644_TrLR.WAV -> nr 10
# Converting: 251124_160441_TrLR.WAV -> nr 10
# Created: D:\legendary_interview\nr 8
# Converting: 251111_133857_TrLR.WAV -> nr 8
# Created: D:\legendary_interview\nr 7
# Created: D:\legendary_interview\nr 6
# Converting: 111125_125651_TrLR.WAV -> nr 6
# Created: D:\legendary_interview\nr 5
# Converting: 251112_120906_TrLR.WAV -> nr 5
# Created: D:\legendary_interview\nr 4
# Converting: 251110_173149_TrLR.WAV -> nr 4
# Created: D:\legendary_interview\nr 3
# Converting: 251126_180539_TrLR.WAV -> nr 3
# Created: D:\legendary_interview\nr 2
# Converting: 251124_102702_TrLR.WAV -> nr 2
# Created: D:\legendary_interview\nr 1
