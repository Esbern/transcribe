# %% [markdown]
# # ✍️ QualiVault: Transcribe
# **Goal:** Transcribe processed FLAC files using Whisper and Pyannote.
#
# 1. Loads `processing_recipe.yaml`.
# 2. Iterates through 'pending' interviews.
# 3. Runs Diarization (Speaker ID) and Transcription.
# 4. Uses 'Hybrid' logic (Left/Right channel check) if separation is good.
# 5. Saves a CSV transcript for each interview.

# %%
# %load_ext autoreload
# %autoreload 2
import json
import yaml
from pathlib import Path
from qualivault.core import setup_environment
from qualivault import find_workspace_root

# 1. Setup Environment (Load Token & Config)
setup_environment()

# 2. Load Config Paths
PROJECT_NAME = 'Legundary'  # <-- Change this to work on different projects
workspace_root = find_workspace_root(Path.cwd())
project_root = workspace_root / 'projects' / PROJECT_NAME
config_path = project_root / 'config.yml'

if not project_root.exists():
    raise FileNotFoundError(f"❌ Project not found: {project_root}")
if not config_path.exists():
    raise FileNotFoundError(f"❌ Config not found: {config_path}")

with open(config_path) as f:
    config = yaml.safe_load(f)

recipe_path = project_root / "processing_recipe.yaml"

print(f"📁 Project: {project_root.name}")
print(f"📄 Recipe: {recipe_path}")
print(f"⚙️  Transcription backend: {config.get('transcription', {}).get('backend', 'auto')}")
print(f"🤖 Model: {config.get('transcription', {}).get('model_id', 'openai/whisper-large-v3')}")

# %%
# 3. Run Transcription Loop (resumable)
from qualivault.pipeline import transcribe_recipe

FORCE_REPROCESS = True  # False: process pending interviews and skip existing CSVs
RESUME = not FORCE_REPROCESS

# Selection mode:
# - None => use MAX_INTERVIEWS (count-based)
# - []   => all interviews
# - [1, 12, 154] => only those interview IDs (or stems like "Interview_154")
INTERVIEW_IDS = []
MAX_INTERVIEWS = None  # Used only when INTERVIEW_IDS is None

with open(recipe_path) as f:
    recipe = yaml.safe_load(f) or []

def _normalize_token(x):
    s = str(x).strip()
    if s.lower().startswith("interview_"):
        s = s.split("_", 1)[1]
    return s

def _matches_requested(item, requested):
    out_name = str(item.get('output_name', ''))
    stem = Path(out_name).stem if out_name else ''
    iid = str(item.get('id', '')).strip()

    # Candidate forms we accept for matching
    candidates = set()
    if iid:
        candidates.add(_normalize_token(iid))
    if stem:
        candidates.add(_normalize_token(stem))

    return any(tok in candidates for tok in requested)

if INTERVIEW_IDS is None:
    subset = recipe[:MAX_INTERVIEWS] if MAX_INTERVIEWS is not None else recipe
    selected_recipe_path = recipe_path
else:
    if len(INTERVIEW_IDS) == 0:
        subset = recipe
    else:
        requested = {_normalize_token(x) for x in INTERVIEW_IDS}
        subset = [item for item in recipe if _matches_requested(item, requested)]

    # Write a temporary filtered recipe so transcribe_recipe can process exact interviews.
    selected_recipe_path = project_root / "processing_recipe.selected.yaml"
    with open(selected_recipe_path, "w", encoding="utf-8") as f:
        yaml.safe_dump(subset, f, sort_keys=False, allow_unicode=True)

output_dir = (project_root / config['paths']['output_base_folder']).resolve()

existing_csv = 0
for item in subset:
    out_name = str(item.get('output_name', ''))
    csv_name = out_name.replace('.flac', '.csv') if out_name.endswith('.flac') else f"{out_name}.csv"
    if (output_dir / csv_name).exists():
        existing_csv += 1

# Verify which config values will be used by transcribe_recipe.
tx_cfg = (config or {}).get('transcription', {})

# Optional: force batch decode settings from a known-good tuning manifest.
APPLY_TUNING_MANIFEST = False
TUNING_MANIFEST = project_root / 'tuning_exports' / 'Interview_1' / '20260314_115544' / 'run_manifest.json'
MANUAL_REPETITION_PENALTY = None  # Set a float (e.g. 1.25) to override config

if APPLY_TUNING_MANIFEST and TUNING_MANIFEST.exists():
    with open(TUNING_MANIFEST, 'r', encoding='utf-8') as f:
        m = json.load(f)

    p = (m or {}).get('parameters', {})
    d = p.get('decode', {}) or {}
    w = p.get('window', {}) or {}
    diar_m = p.get('diarization', {}) or {}

    tx_cfg['num_beams'] = d.get('num_beams', tx_cfg.get('num_beams'))
    tx_cfg['condition_on_prev_tokens'] = d.get('condition_on_prev_tokens', tx_cfg.get('condition_on_prev_tokens'))
    tx_cfg['no_speech_threshold'] = d.get('no_speech_threshold', tx_cfg.get('no_speech_threshold'))
    tx_cfg['repetition_penalty'] = d.get('repetition_penalty', tx_cfg.get('repetition_penalty'))
    tx_cfg['chunk_length_s'] = d.get('chunk_length_s', tx_cfg.get('chunk_length_s', 30))
    tx_cfg['stride_left_s'] = d.get('stride_left_s', tx_cfg.get('stride_left_s', 5))
    tx_cfg['stride_right_s'] = d.get('stride_right_s', tx_cfg.get('stride_right_s', 5))

    seg_cfg = tx_cfg.setdefault('segmentation', {})
    seg_cfg['transcribe_mode'] = 'full_audio_windowed'
    seg_cfg['full_audio_window_s'] = float(w.get('duration_s', seg_cfg.get('full_audio_window_s', 180.0)))
    seg_cfg['full_audio_window_overlap_s'] = float(w.get('right_context_s', seg_cfg.get('full_audio_window_overlap_s', 8.0)))
    seg_cfg['use_tuning_decode_path'] = True
    seg_cfg['tuning_left_context_s'] = float(w.get('left_context_s', seg_cfg.get('tuning_left_context_s', 35.0)))
    seg_cfg['tuning_right_context_s'] = float(w.get('right_context_s', seg_cfg.get('tuning_right_context_s', 14.0)))

    pre_cfg = tx_cfg.setdefault('preprocessing', {})
    pre_cfg['trim_silence'] = False
    pre_cfg['normalize_audio'] = False

    diar_cfg = tx_cfg.setdefault('diarization', {})
    if 'min_speakers' in diar_m:
        diar_cfg['min_speakers'] = int(diar_m['min_speakers'])
    if 'max_speakers' in diar_m:
        diar_cfg['max_speakers'] = int(diar_m['max_speakers'])

    print(f"🧪 Applied tuning manifest: {TUNING_MANIFEST.name}")
    print(f"   decode: beams={tx_cfg.get('num_beams')}, condition_on_prev_tokens={tx_cfg.get('condition_on_prev_tokens')}, repetition_penalty={tx_cfg.get('repetition_penalty')}")
    print(f"   chunk/stride: {tx_cfg.get('chunk_length_s')}/{tx_cfg.get('stride_left_s')}/{tx_cfg.get('stride_right_s')}")
    print(f"   window: {seg_cfg.get('full_audio_window_s')}s overlap {seg_cfg.get('full_audio_window_overlap_s')}s")
    print(f"   tuning context L/R: {seg_cfg.get('tuning_left_context_s')}s / {seg_cfg.get('tuning_right_context_s')}s")
    print(f"   diarization: min={diar_cfg.get('min_speakers')}, max={diar_cfg.get('max_speakers')}")
    print(f"   preprocessing: trim_silence={pre_cfg.get('trim_silence')}, normalize_audio={pre_cfg.get('normalize_audio')}")

if MANUAL_REPETITION_PENALTY is not None:
    tx_cfg['repetition_penalty'] = float(MANUAL_REPETITION_PENALTY)
    print(f"🛠️ Manual repetition_penalty override: {tx_cfg['repetition_penalty']}")

overrides_cfg = tx_cfg.get('interview_overrides', {}) if isinstance(tx_cfg.get('interview_overrides', {}), dict) else {}

def _candidate_keys(item):
    out_name = str(item.get('output_name', ''))
    stem = Path(out_name).stem if out_name else ''
    iid = item.get('id')
    keys = [stem]
    if iid is not None:
        keys.extend([str(iid), f"Interview_{iid}"])
    return [k for k in keys if k]

matched_overrides = []
for item in subset:
    for k in _candidate_keys(item):
        if k in overrides_cfg:
            matched_overrides.append(k)
            break

print(f"🧪 Selected interviews: {len(subset)}")
if INTERVIEW_IDS is None:
    print(f"🔢 Selection mode: count-based (MAX_INTERVIEWS={MAX_INTERVIEWS})")
elif len(INTERVIEW_IDS) == 0:
    print("🗂️ Selection mode: all interviews")
else:
    print(f"🧾 Selection mode: explicit IDs {INTERVIEW_IDS}")
print(f"📄 Existing CSVs in selection: {existing_csv}")
print(f"🔁 Resume mode: {RESUME}")
if RESUME and existing_csv > 0:
    print("ℹ️ Existing CSV files will be skipped in resume mode.")
if not RESUME:
    print("⚠️ FORCE_REPROCESS is ON: existing CSV files will be overwritten.")

print("\n⚙️ Effective default transcription settings loaded from config:")
print(f"  num_beams={tx_cfg.get('num_beams')}, condition_on_prev_tokens={tx_cfg.get('condition_on_prev_tokens')}")
print(f"  no_speech_threshold={tx_cfg.get('no_speech_threshold')}, repetition_penalty={tx_cfg.get('repetition_penalty')}")
print(f"  chunk_length_s={tx_cfg.get('chunk_length_s', 30)}, stride_left_s={tx_cfg.get('stride_left_s', 5)}, stride_right_s={tx_cfg.get('stride_right_s', 5)}")
print(f"  denoise_strength={((tx_cfg.get('preprocessing') or {}).get('denoise_strength'))}")

print(f"\n🧩 Per-interview overrides found in config: {len(overrides_cfg)}")
if matched_overrides:
    print(f"✅ Overrides matched for selected interviews: {', '.join(sorted(set(matched_overrides)))}")
else:
    print("ℹ️ No interview overrides matched in this selection. Defaults will be used.")

final_rep = float(tx_cfg.get('repetition_penalty', 1.0))
if MANUAL_REPETITION_PENALTY is not None:
    expected_rep = float(MANUAL_REPETITION_PENALTY)
    if abs(final_rep - expected_rep) > 1e-9:
        raise RuntimeError(f"Manual repetition penalty not applied (expected {expected_rep}, got {final_rep}).")
print(f"🧪 Preflight decode check: repetition_penalty={final_rep}")

transcribe_recipe(
    project_root=project_root,
    config=config,
    recipe_path=selected_recipe_path,
    resume=RESUME,
    max_items=None,  # selection already applied above
)
